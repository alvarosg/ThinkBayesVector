# %%
import scipy.stats
import os
import csv
from scipy.special import erf, erfinv
import numpy as np
# %matplotlib nbagg
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,1.,101)
prior=x*0+1

prior=prior/prior.sum()


posterior=prior*((1-x)**110)*((x)**140)

posterior=posterior/posterior.sum()

plt.figure()
plt.plot(x,prior)
plt.plot(x,posterior)
# Out:
# <img src="data:image/png;base64,...">

# %%
posterior
# Out:
# array([  0.00000000e+000,   1.25633046e-207,   5.73192108e-166,
#          8.33871083e-142,   8.26926488e-125,   9.65227468e-112,
#          3.66835564e-101,   2.66736487e-092,   1.06780431e-084,
#          4.65304187e-078,   3.51486397e-072,   6.41370730e-067,
#          3.61161016e-062,   7.55822114e-058,   6.79183482e-054,
#          2.93826241e-050,   6.71044810e-047,   8.72311580e-044,
#          6.86921263e-041,   3.45214233e-038,   1.15699224e-035,
#          2.68481143e-033,   4.45465520e-031,   5.43387063e-029,
#          4.99230918e-027,   3.52835822e-025,   1.95429612e-023,
#          8.62331159e-022,   3.07561152e-020,   8.98194825e-019,
#          2.17266389e-017,   4.39814559e-016,   7.51986157e-015,
#          1.09499557e-013,   1.36808720e-012,   1.47648121e-011,
#          1.38477664e-010,   1.13483911e-009,   8.16623464e-009,
#          5.18273876e-008,   2.91251930e-007,   1.45443295e-006,
#          6.47459237e-006,   2.57662009e-005,   9.18946361e-005,
# ...
